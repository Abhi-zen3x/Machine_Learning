# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi-zen3x/Machine_Learning/blob/main/Regularization_RIDGe_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**REGULARIZATION**

# %% [markdown]
# ###**IMPORTING MODULE**

# %%
import numpy as np
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_absolute_error,r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ###**LOADING DATA**

# %%
x = np.array([[12],[23],[34],[45],[56],[67],[78],[89],[123],[134]])
Y= np.array([240,1135,2568,4521,7865,9236,11932,14589,19856,23145])

# %% [markdown]
# ###**TRAINING MODEL**

# %%
model=RidgeCV()
poly=PolynomialFeatures(degree=10)
X=poly.fit_transform(x)
model.fit(X,Y)
# Out:
# RidgeCV()

# %% [markdown]
# ###**PREDICTING OUTPUT**

# %%
Y_predict=model.predict(X)

# %% [markdown]
# ###**EVALUATION**

# %%
mae=mean_absolute_error(Y,Y_predict)
r2=r2_score(Y,Y_predict)
print("Mean absolute error:",mae)
print("R2 score:",r2)
# Out:
# Mean absolute error: 14970.581424592214
# R2 score: -7.283457392266987

# %% [markdown]
# ###**PLOTING GRAPH**

# %%
plt.figure(figsize=[5,5])
plt.scatter(x,Y,s=40,c='yellow',label='datapoints',marker='*',edgecolors='green')
plt.plot(x,Y_predict,c='red',label='regression')
plt.xlabel('Feature')
plt.ylabel('label')
plt.title('Lir REg')
plt.legend()
plt.show()
