# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi-zen3x/Machine_Learning/blob/main/POLYNOMIAL_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**POLYNOMIAL REGRESSION**

# %% [markdown]
# ###**IMPORTING MODULE**

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ###**INITIALIZING DATA**

# %%
x = np.array([[12],[23],[34],[45],[56],[67],[78],[89],[123],[134]])
Y= np.array([240,1135,2568,4521,7865,9236,11932,14589,19856,23145])

# %% [markdown]
# ###**TRAINING DATA**

# %%
mni=LinearRegression()
poly=PolynomialFeatures(degree=10)
X=poly.fit_transform(x)
mni.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# ###**PREDICTING OUTPUT**

# %%
Y_predict=mni.predict(X)

# %% [markdown]
# ###**EVALUATON**

# %%
mae=mean_absolute_error(Y,Y_predict)
r2=r2_score(Y,Y_predict)
print("Mean absolute error:",mae)
print("R2 Score:",r2)
# Out:
# Mean absolute error: 276.6720770301967
# R2 Score: 0.9975611442162389

# %% [markdown]
# ###**PLOTING GRAPH**

# %%
plt.figure(figsize=[5,5])
plt.scatter(x,Y,s=40,c='yellow',label='datapoints',marker='*',edgecolors='green')
plt.plot(x,Y_predict,c='red',label='regression')
plt.xlabel('Feature')
plt.ylabel('label')
plt.title('Lir REg')
plt.legend()
plt.show()
